# %% [markdown]
# # Expected locking temperature for different materials

# %%
from pylab import plot, show, xlabel, ylabel, legend, semilogy,semilogx, grid, xlim, ylim, title,savefig, minorticks_on, figtext
import math
from math import e
import numpy as np
import matplotlib.pylab as pylab
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (16, 9),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
pylab.rcParams.update(params)
from sympy.solvers import solve
from sympy import Symbol, log, sqrt
import pandas as pd
import datetime
from datetime import timedelta
from datetime import datetime

# %% [markdown]
# Import the data from sheet

# %%
data=pd.read_excel("Pyrometer_data_2021_06_09.xlsx")   #Import the experimental data
data.time = [datetime.strptime(x,'%H:%M:%S.%f') for x in data.time] # converts the time strings to readable datetime
t_diff= [(data.time.diff()).iloc[x].seconds for x in range(len(data))]; # determine the difference between two lines
tstart=data[(np.array(t_diff)>120)] #when the difference is larger than 2min (120sec) the expriment has ended 
tend=data.iloc[tstart.index-1]

# %%
starttime=data.time[np.argmax(data.time>datetime.strptime('12:16:00','%H:%M:%S'))] # the time of the frist experiment

endindex=np.argmax(tend.time>starttime)

def exp(starttime,endindex):
    endtime=tend.iloc[endindex,0] #endtime of the first experiment 
    Exp=data.loc[(data.loc[data.time==starttime]).index.values[0]:(data.loc[data.time==endtime]).index.values[0]]
    t = [(x-starttime).total_seconds() for x in Exp.time]
    return t,Exp

# %%
print(tstart.iloc[2].time)
print(starttime)
# Out:
# 1900-01-01 12:16:33.453000
# 1900-01-01 12:16:33.453000

# %%
fig,ax=pylab.subplots()
ax.plot(exp(starttime,endindex)[0],exp(starttime,endindex)[1].temp, 'k*-')
ax.plot(exp(tstart.iloc[3].time,endindex+1)[0],exp(tstart.iloc[3].time,endindex+1)[1].temp, 'r*-')
ax.plot(exp(tstart.iloc[4].time,endindex+2)[0],exp(tstart.iloc[4].time,endindex+2)[1].temp, 'b*-')
ax.plot(exp(tstart.iloc[5].time,endindex+3)[0],exp(tstart.iloc[5].time,endindex+3)[1].temp, 'y*-')
xlabel('$time$ $[s]$') 
ylabel('$T$ $[\degree C]$')
ax.yaxis.label.set_color('black')
grid(b=True, which='major', color='#666666')
minorticks_on()
grid(b=True, which='minor', color='#999999', alpha=0.2)
#ylim(0,1200)

#ax2=ax.twinx()
#ax2.plot(t_exp1,Exp1.tol, 'r*-')
#ylabel('Tolerance $[\degree C]$')
#ax2.yaxis.label.set_color('red')
#ylim(0,50)

title('Temperature pyrometer')
# Out:
# Text(0.5, 1.0, 'Temperature pyrometer')

# %%
data.time[np.argmax(data.time>datetime.strptime('12:21:30','%H:%M:%S'))]
#(data.time[1]-data.time[0]).total_seconds()>60
#next(x for x, val in enumerate(data.time.diff.total_seconds()()) if val > 60)
#iets=data.time.diff()
#iets[1].total_seconds()

# %%
tend

# %%
(data.loc[data.time==starttime]).index.values[0]
